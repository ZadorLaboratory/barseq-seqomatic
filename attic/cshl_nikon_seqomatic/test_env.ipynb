# %% [markdown]
# ### All packages used in this GUI, test if you have any compatible issue

# %%
from pycromanager import Core
from pycromanager import Acquisition, multi_d_acquisition_events
import pandas as pd
import nidaqmx
import nidaqmx.system
import json
import serial
import numpy as np
from datetime import datetime
import os
import time
from matplotlib import pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from PIL import Image, ImageSequence
from PIL import ImageTk, Image
import tkinter as tk
import time
import tkinter as tk
from tkinter import *
from tkinter import ttk,scrolledtext
import shutil
import tifffile
from pytz import timezone
from typing import List
import threading
import queue
import math
from tkinter import ttk, StringVar,filedialog,messagebox,scrolledtext,Button
import copy
import subprocess
import warnings
import cv2

# %% [markdown]
# ### Test the jave bridge of pycromanager and micromanager, please keep miceomanager opened

# %%
core=Core()
print(core)
